# %%
import re
import torch
import numpy as np

# %%
from transformers import *

# %%
from util.util import *

# %%
# model = TransfoXLModel.from_pretrained('transfo-xl-wt103')
model = XLNetModel.from_pretrained('xlnet-large-cased')
model.eval()
# Out:
# XLNetModel(
#   (word_embedding): Embedding(32000, 1024)
#   (layer): ModuleList(
#     (0): XLNetLayer(
#       (rel_attn): XLNetRelativeAttention(
#         (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): XLNetFeedForward(
#         (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (layer_1): Linear(in_features=1024, out_features=4096, bias=True)
#         (layer_2): Linear(in_features=4096, out_features=1024, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (1): XLNetLayer(
#       (rel_attn): XLNetRelativeAttention(
#         (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): XLNetFeedForward(
#         (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
# ...

# %%
modelLM = XLNetLMHeadModel.from_pretrained('xlnet-large-cased')
modelLM.eval()
# Out:
# XLNetLMHeadModel(
#   (transformer): XLNetModel(
#     (word_embedding): Embedding(32000, 1024)
#     (layer): ModuleList(
#       (0): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=1024, out_features=4096, bias=True)
#           (layer_2): Linear(in_features=4096, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
# ...

# %%
tokenizer = XLNetTokenizer.from_pretrained('xlnet-large-cased')

# %%
filename = "/data/medg/misc/phuongpm/" + "sample1.0.json"

# %%
data = JsonDataset(filename)

# %%
sample_data = list(data.json_to_plain(remove_notfound=False))

# %%
input0 = sample_data[1]

# %%
input0['a']
# Out:
# 'arterial injuries'

# %%
input0['c']
# Out:
# ['capillary filling time',
#  'patent small ulnar artery',
#  'spontaneous rupture of these lesions',
#  'lesion ruptured',
#  'traumatic lacerations',
#  'oral warfarin',
#  'hypovolaemia',
#  'clots',
#  'dual roots of circulation and adequate back bleeding from the distal stump',
#  'surgical procedure',
#  'prolene sutures',
#  'rupture',
#  'release of the bulldog vascular clamps',
#  'aneurysm sac',
#  'ligation',
#  'direct iatrogenic puncture',
#  'repeat doppler study',
#  'examination',
#  'sutures',
#  'laceration over the right wrist',
#  'pneumatic tourniquet',
#  'pseudoaneurysm of the radial artery',
#  'pseudoaneurysms',
#  'suture marks',
#  'poor distal capillary filling',
#  'swelling',
#  'false aneurysm of the radial artery',
#  'angiography',
#  'iatrogenic arterial puncture',
#  'radial artery cannulation',
#  'swelling non-pulsatile',
#  'intermittently bleeding',
#  'ulnar artery pulsation',
#  'culture and sensitivity',
#  'false aneurysm',
#  'laceration',
# ...

# %%
input0['p']
# Out:
# 'ruptured pseudoaneurysm of the radial artery summary  a 40 - year - old man presented with a progressively increasing swelling over the ventral aspect of the right wrist of 23 days duration following a laceration . the swelling was soft , pulsatile and was intermittently bleeding , with poor distal capillary filling and cold distal extremity . clinically it was diagnosed as pseudoaneurysm of the radial artery and was sent for a duplex scan for confirmation . the lesion ruptured in the radiology department before the scan was done , and the patient went into hypovolaemia . in view of this , the patient underwent exploration of the pseudoaneurysm under brachial block , and the radial artery was found to be transected just proximal to the dorsal branch . it was decided to repair the artery as there was no evidence of adequate circulation supply or the patency of the ulnar artery preoperatively . doppler study at 15 and 45 days postoperatively showed good flow through , with no evidence
# ...

# %%
input_ids = torch.tensor(tokenizer.encode(input0['p'], add_special_tokens=True)).unsqueeze(0)

# %%
perm_mask = torch.zeros((1, input_ids.shape[1], input_ids.shape[1]), dtype=torch.float)
perm_mask[:, :, -1] = 1.0  # Previous tokens don't see last token

# %%
target_mapping = torch.zeros((1, 1, input_ids.shape[1]), dtype=torch.float)

# %%
target_mapping[0, 0, -1] = 1.0

# %%
outputs = model(input_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-cb3d7e3bd77c> in <module>
# ----> 1 outputs = model(input_ids)
#
# /scratch/conda_envs/squad/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /scratch/conda_envs/squad/lib/python3.6/site-packages/transformers/modeling_xlnet.py in forward(self, input_ids, attention_mask, mems, perm_mask, target_mapping, token_type_ids, input_mask, head_mask, inputs_embeds)
#     910                 mems=mems[i],
#     911                 target_mapping=target_mapping,
# ...

# %%
next_token_logits

# %%
tokenizer.tokenize('interstitium')
# Out:
# ['▁inter', 'sti', 't', 'ium']
